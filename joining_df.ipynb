# %% [markdown]
# # Joining DataFrame
#
# #### Loading Libraries

# %%
# Data Manipulation
import pandas as pd
# Numerical Computing
import numpy as np
# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Adding Rows to DataFrame

# %%
df1 = pd.DataFrame({'name': ['John', 'George', 'Ringo'], 
                    'color': ['Blue', 'Blue', 'Purple']})
df2 = pd.DataFrame({'name': ['Paul', 'George', 'Ringo'], 
                    'carcolor': ['Red', 'Blue', np.nan]},
                   index=[3, 1, 2])

# %%
pd.concat([df1, df2])
# Out:
#      name   color carcolor
# 0    John    Blue      NaN
# 1  George    Blue      NaN
# 2   Ringo  Purple      NaN
# 3    Paul     NaN      Red
# 1  George     NaN     Blue
# 2   Ringo     NaN      NaN

# %%
# Verify Integrity Parameter
# pd.concat([df1, df2], verify_integrity=True)

# %%
# Setting Pandas New Index
pd.concat([df1, df2], ignore_index=True)
# Out:
#      name   color carcolor
# 0    John    Blue      NaN
# 1  George    Blue      NaN
# 2   Ringo  Purple      NaN
# 3    Paul     NaN      Red
# 4  George     NaN     Blue
# 5   Ringo     NaN      NaN

# %% [markdown]
# #### Adding Columns to DataFrame

# %%
pd.concat([df1, df2], axis=1)
# Out:
#      name   color    name carcolor
# 0    John    Blue     NaN      NaN
# 1  George    Blue  George     Blue
# 2   Ringo  Purple   Ringo      NaN
# 3     NaN     NaN    Paul      Red

# %% [markdown]
# #### Joins

# %%
df1.set_index('name').join(df2.set_index('name'))
# Out:
#          color carcolor
# name
# John      Blue      NaN
# George    Blue     Blue
# Ringo   Purple      NaN

# %%
df1.merge(df2)
# Out:
#      name   color carcolor
# 0  George    Blue     Blue
# 1   Ringo  Purple      NaN

# %%
df1.merge(df2, how='outer')
# Out:
#      name   color carcolor
# 0  George    Blue     Blue
# 1    John    Blue      NaN
# 2    Paul     NaN      Red
# 3   Ringo  Purple      NaN

# %%
df1.merge(df2, how='left')
# Out:
#      name   color carcolor
# 0    John    Blue      NaN
# 1  George    Blue     Blue
# 2   Ringo  Purple      NaN

# %%
df1.merge(df2, how='right')
# Out:
#      name   color carcolor
# 0    Paul     NaN      Red
# 1  George    Blue     Blue
# 2   Ringo  Purple      NaN

# %%
df1.merge(df2, how='right', left_on='color', right_on='carcolor')
# Out:
#    name_x color  name_y carcolor
# 0     NaN   NaN    Paul      Red
# 1    John  Blue  George     Blue
# 2  George  Blue  George     Blue
# 3     NaN   NaN   Ringo      NaN

# %% [markdown]
# #### Join Indecators

# %%
df1.merge(df2, how='outer', indicator=True)
# Out:
#      name   color carcolor      _merge
# 0  George    Blue     Blue        both
# 1    John    Blue      NaN   left_only
# 2    Paul     NaN      Red  right_only
# 3   Ringo  Purple      NaN        both

# %% [markdown]
# ### Dirty Devil Flow & Weather Data

# %%
url = 'https://github.com/mattharrison/datasets/raw/master/data/'\
      'dirtydevil.txt'
df = pd.read_csv(url, skiprows=lambda num: num <34 or num == 35,
                 sep='\t')
# Out:
# /var/folders/dk/f9pbhbp52qxc0613mpbtx8lm0000gn/T/ipykernel_12610/4040420796.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url, skiprows=lambda num: num <34 or num == 35,

# %%
def to_us_mountain_time(df_, time_col, tz_col):
    return (df_
            .assign(**{tz_col: df_[tz_col].replace('MDT',
                       'MST7MDT')})

            .groupby(tz_col)
            [time_col]
            .transform(lambda s: pd.to_datetime(s)
                .dt.tz_localize(s.name, ambiguous=True)
                .dt.tz_convert('US/Mountain'))
           )

# %%
def tweak_river(df_):
    return (df_
      .assign(datetime=to_us_mountain_time(df_, 'datetime', 'tz_cd'))
      .rename(columns={'144166_00060': 'cfs',
                       '144167_00065': 'gage_height'})
    )

# %%
dd = tweak_river(df)

# %%
dd
# Out:
#        agency_cd  site_no                  datetime tz_cd    cfs  \
# 0           USGS  9333500 2001-05-07 01:00:00-06:00   MDT  71.00
# 1           USGS  9333500 2001-05-07 01:15:00-06:00   MDT  71.00
# 2           USGS  9333500 2001-05-07 01:30:00-06:00   MDT  71.00
# 3           USGS  9333500 2001-05-07 01:45:00-06:00   MDT  70.00
# 4           USGS  9333500 2001-05-07 02:00:00-06:00   MDT  70.00
# ...          ...      ...                       ...   ...    ...
# 539300      USGS  9333500 2020-09-28 08:30:00-06:00   MDT   9.53
# 539301      USGS  9333500 2020-09-28 08:45:00-06:00   MDT   9.20
# 539302      USGS  9333500 2020-09-28 09:00:00-06:00   MDT   9.20
# 539303      USGS  9333500 2020-09-28 09:15:00-06:00   MDT   9.20
# 539304      USGS  9333500 2020-09-28 09:30:00-06:00   MDT   9.20
#
#        144166_00060_cd  gage_height 144167_00065_cd
# 0               A:[91]          NaN             NaN
# 1               A:[91]          NaN             NaN
# 2               A:[91]          NaN             NaN
# 3               A:[91]          NaN             NaN
# 4               A:[91]          NaN             NaN
# ...                ...          ...             ...
# 539300               P         6.16               P
# 539301               P         6.15               P
# 539302               P         6.15               P
# 539303               P         6.15               P
# 539304               P         6.15               P
#
# [539305 rows x 8 columns]

# %% [markdown]
# #### Loading Hanksville Meteorological Data

# %%
url = 'https://github.com/mattharrison/datasets/raw/master/data/'\
      'hanksville.csv'

# %%
temp_df = pd.read_csv(url)
def tweak_temp(df_):
    return (df_
           .assign(DATE=pd.to_datetime(df_.DATE)
                .dt.tz_localize('US/Mountain', ambiguous=False))
           .loc[:,['DATE', 'PRCP', 'TMIN', 'TMAX', 'TOBS']]
    )

# %%
temp_df = tweak_temp(temp_df)
temp_df
# Out:
#                           DATE  PRCP  TMIN  TMAX  TOBS
# 0    2000-01-01 00:00:00-07:00  0.02  21.0  43.0  28.0
# 1    2000-01-02 00:00:00-07:00  0.03  24.0  39.0  24.0
# 2    2000-01-03 00:00:00-07:00  0.00   7.0  39.0  18.0
# 3    2000-01-04 00:00:00-07:00  0.00   5.0  39.0  25.0
# 4    2000-01-05 00:00:00-07:00  0.00  10.0  44.0  22.0
# ...                        ...   ...   ...   ...   ...
# 6843 2020-09-20 00:00:00-06:00  0.00  46.0  92.0  83.0
# 6844 2020-09-21 00:00:00-06:00  0.00  47.0  92.0  84.0
# 6845 2020-09-22 00:00:00-06:00  0.00  54.0  84.0  77.0
# 6846 2020-09-23 00:00:00-06:00  0.00  47.0  91.0  87.0
# 6847 2020-09-24 00:00:00-06:00  0.00  43.0  94.0  88.0
#
# [6848 rows x 5 columns]

# %% [markdown]
# #### Joining Data

# %%
(dd
 .merge(temp_df, left_on='datetime', right_on='DATE')
)
# Out:
#      agency_cd  site_no                  datetime tz_cd    cfs  \
# 0         USGS  9333500 2001-05-08 00:00:00-06:00   MDT  75.00
# 1         USGS  9333500 2001-05-09 00:00:00-06:00   MDT  64.00
# 2         USGS  9333500 2001-05-10 00:00:00-06:00   MDT  54.00
# 3         USGS  9333500 2001-05-11 00:00:00-06:00   MDT  56.00
# 4         USGS  9333500 2001-05-12 00:00:00-06:00   MDT  49.00
# ...        ...      ...                       ...   ...    ...
# 4968      USGS  9333500 2020-09-20 00:00:00-06:00   MDT   6.04
# 4969      USGS  9333500 2020-09-21 00:00:00-06:00   MDT   6.83
# 4970      USGS  9333500 2020-09-22 00:00:00-06:00   MDT   6.83
# 4971      USGS  9333500 2020-09-23 00:00:00-06:00   MDT   7.68
# 4972      USGS  9333500 2020-09-24 00:00:00-06:00   MDT   9.86
#
#      144166_00060_cd  gage_height 144167_00065_cd                      DATE  \
# 0             A:[91]          NaN             NaN 2001-05-08 00:00:00-06:00
# 1             A:[91]          NaN             NaN 2001-05-09 00:00:00-06:00
# 2             A:[91]          NaN             NaN 2001-05-10 00:00:00-06:00
# 3             A:[91]          NaN             NaN 2001-05-11 00:00:00-06:00
# 4             A:[91]          NaN             NaN 2001-05-12 00:00:00-06:00
# ...              ...          ...             ...                       ...
# 4968               P         6.04               P 2020-09-20 00:00:00-06:00
# 4969               P         6.07               P 2020-09-21 00:00:00-06:00
# 4970               P         6.07               P 2020-09-22 00:00:00-06:00
# 4971               P         6.10               P 2020-09-23 00:00:00-06:00
# 4972               P         6.17               P 2020-09-24 00:00:00-06:00
#
#       PRCP  TMIN  TMAX  TOBS
# 0      0.0  43.0  85.0  58.0
# 1      0.0  36.0  92.0  64.0
# 2      0.0  50.0  92.0  67.0
# 3      0.0  46.0  87.0  60.0
# 4      0.0  45.0  93.0  72.0
# ...    ...   ...   ...   ...
# 4968   0.0  46.0  92.0  83.0
# 4969   0.0  47.0  92.0  84.0
# 4970   0.0  54.0  84.0  77.0
# 4971   0.0  47.0  91.0  87.0
# 4972   0.0  43.0  94.0  88.0
#
# [4973 rows x 13 columns]

# %%
# (dd
#  .groupby(pd.Grouper(key='datetime', freq='D'))
#  .median()
#  .merge(temp_df, left_index=True, right_on='DATE')
# )

# %% [markdown]
# #### Validating Joined Data

# %%
# (dd
#  .groupby(pd.Grouper(key='datetime', freq='D'))
#  .median()
#  .merge(temp_df, left_index=True, right_on='DATE',
#         how='inner', validate='1:1')
# )

# %% [markdown]
# #### Merged Data Visualization

# %%
# fig, ax = plt.subplots(dpi=600)    # doctest: +SKIP
# (dd   # doctest: +SKIP
#  .groupby(pd.Grouper(key='datetime', freq='D'))
#  .median()
#  .merge(temp_df, left_index=True, right_on='DATE',
#         how='inner', validate='1:1')
#  .set_index('DATE')
#  .loc['2014':,['cfs', 'gage_height', 'PRCP', 'TOBS']]
#  .interpolate()
#  .rolling(15)
#  .mean()
#  .plot(subplots=True, figsize=(10,8), ax=ax)
# )
# fig.suptitle('Dirty Devil Metrics (15 day average)')

# %%
# fig, ax = plt.subplots(dpi=600)
# dd2 = (dd
#  .groupby(pd.Grouper(key='datetime', freq='D'))
#  .median()
#  .merge(temp_df, left_index=True, right_on='DATE',
#         how='inner', validate='1:1')
#  .query('cfs < 400')           
# )
# (dd2
#  .plot.scatter(x='cfs', y='TOBS', c=dd2.DATE.dt.month,
#                ax=ax, cmap='hsv', alpha=.5)           
# )
# ax.set_title('Observation Temperature (TOBS) '
#    'vs River Flow (cubic feet per sec)\nColored by Month')
